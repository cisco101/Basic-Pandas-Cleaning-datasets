# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data.txt',
#  'Implementing Naive Bayes Algorithm Sentiment Analysis Test.ipynb',
#  'ioc_hash_cleaned_finaldata.csv',
#  'newsmallgray.png',
#  'Numpy_Tests.ipynb',
#  'otx-hash-iocs_unstructured_training_with_exploit links.csv',
#  'pandas-ioc-cleaningup-steps-success.ipynb',
#  'pandas_tutorials_csv.ipynb',
#  'smallgray.png',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Training Datasets',
#  'Untitled.ipynb']

# %%
import pandas as pd
df1=pd.read_csv("otx-hash-iocs_unstructured_training_with_exploit links.csv")
df1
# Out:
#                                                     HASH  \
# 0      176AD6129ECE312F128A3195BF5AFC130801F2E849F89B...
# 1      6374349443708C96AD41B3F9B891B33F7DEC65FDF13E6B...
# 2      6F2C41E665AAB873D213583697D70EE79AD59A2B649164...
# 3      862C6EF1D24D2CBA9878B5E919683629C3516D9121F5CF...
# 4      EAF0F57CBCBDA0DBD2C60C5719731DDEAB76B6A10367D2...
# ...                                                  ...
# 49433           241075FC1493172C47D881BCBFBF21CFA4DAA42D
# 49434           C86B13378BA2A41684E1F93B4C20E05FC5D3D5A3
# 49435           51AC683DF63FF71A0003CA17E640BBEAAA14D0AA
# 49436           B491C14D8CFB48636F6095B7B16555E9A575D57F
# 49437           82448EB23EA9EB3939B6F24DF46789BF7F2D43E3
#
#                                                      CVE Unnamed: 2  \
# 0      Flash Exploit, CVE-2018-4878, Spotted in The W...        NaN
# 1      Flash Exploit, CVE-2018-4878, Spotted in The W...        NaN
# 2      Flash Exploit, CVE-2018-4878, Spotted in The W...        NaN
# ...

# %%
df1=pd.read_csv("otx-hash-iocs_unstructured_training_with_exploit links.csv", header= None)
df1
# Out:
#                                                        0  \
# 0                                                   HASH
# 1      176AD6129ECE312F128A3195BF5AFC130801F2E849F89B...
# 2      6374349443708C96AD41B3F9B891B33F7DEC65FDF13E6B...
# 3      6F2C41E665AAB873D213583697D70EE79AD59A2B649164...
# 4      862C6EF1D24D2CBA9878B5E919683629C3516D9121F5CF...
# ...                                                  ...
# 49434           241075FC1493172C47D881BCBFBF21CFA4DAA42D
# 49435           C86B13378BA2A41684E1F93B4C20E05FC5D3D5A3
# 49436           51AC683DF63FF71A0003CA17E640BBEAAA14D0AA
# 49437           B491C14D8CFB48636F6095B7B16555E9A575D57F
# 49438           82448EB23EA9EB3939B6F24DF46789BF7F2D43E3
#
#                                                        1    2    3    4
# 0                                                    CVE  NaN  NaN  NaN
# 1      Flash Exploit, CVE-2018-4878, Spotted in The W...  NaN  NaN  NaN
# ...

# %%
df1.columns= ["HASH", "EXPLOIT", "M", "N", "O"]
df1
# Out:
#                                                     HASH  \
# 0                                                   HASH
# 1      176AD6129ECE312F128A3195BF5AFC130801F2E849F89B...
# 2      6374349443708C96AD41B3F9B891B33F7DEC65FDF13E6B...
# 3      6F2C41E665AAB873D213583697D70EE79AD59A2B649164...
# 4      862C6EF1D24D2CBA9878B5E919683629C3516D9121F5CF...
# ...                                                  ...
# 49434           241075FC1493172C47D881BCBFBF21CFA4DAA42D
# 49435           C86B13378BA2A41684E1F93B4C20E05FC5D3D5A3
# 49436           51AC683DF63FF71A0003CA17E640BBEAAA14D0AA
# 49437           B491C14D8CFB48636F6095B7B16555E9A575D57F
# 49438           82448EB23EA9EB3939B6F24DF46789BF7F2D43E3
#
#                                                  EXPLOIT    M    N    O
# 0                                                    CVE  NaN  NaN  NaN
# 1      Flash Exploit, CVE-2018-4878, Spotted in The W...  NaN  NaN  NaN
# ...

# %%
df1.drop(['M','N','O'], axis=1, inplace=False)
df1
# Out:
#                                                     HASH  \
# 0                                                   HASH
# 1      176AD6129ECE312F128A3195BF5AFC130801F2E849F89B...
# 2      6374349443708C96AD41B3F9B891B33F7DEC65FDF13E6B...
# 3      6F2C41E665AAB873D213583697D70EE79AD59A2B649164...
# 4      862C6EF1D24D2CBA9878B5E919683629C3516D9121F5CF...
# ...                                                  ...
# 49434           241075FC1493172C47D881BCBFBF21CFA4DAA42D
# 49435           C86B13378BA2A41684E1F93B4C20E05FC5D3D5A3
# 49436           51AC683DF63FF71A0003CA17E640BBEAAA14D0AA
# 49437           B491C14D8CFB48636F6095B7B16555E9A575D57F
# 49438           82448EB23EA9EB3939B6F24DF46789BF7F2D43E3
#
#                                                  EXPLOIT    M    N    O
# 0                                                    CVE  NaN  NaN  NaN
# 1      Flash Exploit, CVE-2018-4878, Spotted in The W...  NaN  NaN  NaN
# ...

# %%
df1.drop(0, axis=0, inplace=True)
df1
# Out:
#                                                     HASH  \
# 1      176AD6129ECE312F128A3195BF5AFC130801F2E849F89B...
# 2      6374349443708C96AD41B3F9B891B33F7DEC65FDF13E6B...
# 3      6F2C41E665AAB873D213583697D70EE79AD59A2B649164...
# 4      862C6EF1D24D2CBA9878B5E919683629C3516D9121F5CF...
# 5      EAF0F57CBCBDA0DBD2C60C5719731DDEAB76B6A10367D2...
# ...                                                  ...
# 49434           241075FC1493172C47D881BCBFBF21CFA4DAA42D
# 49435           C86B13378BA2A41684E1F93B4C20E05FC5D3D5A3
# 49436           51AC683DF63FF71A0003CA17E640BBEAAA14D0AA
# 49437           B491C14D8CFB48636F6095B7B16555E9A575D57F
# 49438           82448EB23EA9EB3939B6F24DF46789BF7F2D43E3
#
#                                                  EXPLOIT    M    N    O
# 1      Flash Exploit, CVE-2018-4878, Spotted in The W...  NaN  NaN  NaN
# 2      Flash Exploit, CVE-2018-4878, Spotted in The W...  NaN  NaN  NaN
# ...

# %%
df1.to_csv('ioc_hash_cleaned_finaldata.csv' , index=False)
